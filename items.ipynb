# %%
import os
import re
import csv
import requests
from bs4 import BeautifulSoup as bs
import shadow_useragent

# %%
url = "https://www.zimmo.be/fr/couvin-5660/a-vendre/maison/JQLJU/?search=82d1fed181cf30aaa8408f90d99003d3"

#url = "https://www.zimmo.be/fr/langemark-8920/a-vendre/maison/JHWY7/?search=3ae7b1a98206095502d8253991210414&boosted=1"

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

# %%
requete = requests.get(url, headers=headers)
page = requete.content
soup = bs(page, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>
# <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>
# <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>
# <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="fr">
#  <!--<![endif]-->
#  <head>
#   <!--
#         ...................................................
#         :                    ......                       :
#         :                 .:||||||||:.                    :
#         :                /            \                   :
#         :               (   o      o   )                  :
#         :-------@@@@----------:  :----------@@@@----------:
#         :                     `--'                        :
#         :         K I L R O Y   W A S   H E R E !         :
#         :                                                 :
#         :         https://www.zimmo.be/fr/jobs/           :
#         :.................................................:
#     -->
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
#    <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#    <meta content="#1d559f" name="theme-color"/>
#    <meta content="telephone=no" name="format-detection">
#     <meta content="Envie d'être en &quot;ville&quot; mais pas trop, besoin d'espace et de verdure, pourquoi ne pas jeter un oeil à cette maison en vente? &lt;br /&gt;
# Maison dans une ru..." name="description">
#      <link href="/fr/couvin-5660/a-vendre/maison/JQLJU/" rel="canonical"/>
#      <meta content="gzHRQZdcnECSnv9G-wiFApGtZ6XzufBjUdkfsriqjdI" name="google-site-verification"/>
#      <title>
#       Maison à vendre à Couvin € 165.000 (JQLJU) - Immo Les Eaux Vives | Zimmo
#      </title>
#      <link href="https://www.zimmo.be/apple-touch-icon.png" rel="apple-touch-icon"/>
#      <link href="https://www.zimmo.be/apple-touch-icon-76x76-precomposed.png" rel="apple-touch-icon" sizes="76x76"/>
#      <link href="https://www.zimmo.be/apple-touch-icon-120x120-precomposed.png" rel="apple-touch-icon" sizes="120x120"/>
#      <link href="https://www.zimmo.be/apple-touch-icon-152x152-precomposed.png" rel="apple-touch-icon" sizes="152x152"/>
#      <link href="https://cloud.typography.com/6940836/6119792/css/fonts.css" rel="stylesheet" type="text/css">
#       <link href="/public/css/base.css?v=34571" media="screen" rel="stylesheet">
#        <link href="/public/css/base2.css?v=c6ab3" media="screen" rel="stylesheet">
#         <script type="text/javascript">
#          if (!!navigator.userAgent.match(/Trident/)) {
#             document.write("<link rel=\"stylesheet\" href=\"\/public\/css\/ie.css?v=d313b\" media=\"screen, projection\" \/>")
#         }
#         </script>
#         <script>
#          // set language for Didomi
#     function getCookie (cName) {
#         var cStart, cEnd;
#         if (document.cookie.length > 0) {
#             cStart = document.cookie.indexOf(cName + "=");
#             if (cStart !== -1) {
#                 cStart = cStart + cName.length + 1;
#                 cEnd = document.cookie.indexOf(";", cStart);
#                 if (cEnd === -1) {
#                     cEnd = document.cookie.length;
#                 }
#                 return unescape(document.cookie.substring(cStart, cEnd));
#             }
#         }
#         return "";
#     }
#
#     var locale = "",
#     cookieLocale = getCookie("Locale"),
#     globalLocale = typeof LOCALE !== "undefined" ? LOCALE : ""; // eslint-disable-line no-undef
#     if (cookieLocale === "nl") {
#         locale = "nl";
#     }
#     if (cookieLocale === "fr" || globalLocale === "fr") {
#         locale = "fr";
#     }
#
#     if (locale === "") {
#         // if locale still isn't found, check url
#         var url = window.location.href;
#         if (url.includes("/nl/")) {
#             locale = "nl";
#         }
#         if (url.includes("/fr/")) {
#             locale = "fr";
#         }
#     }
#
#     if (locale !== "") {
#         window.didomiConfig = {
#             languages: {
#                 enabled: [locale],
#                 default: locale
#             }
#         };
#     }
#         </script>
#         <!-- Didomi -->
#         <script type="text/javascript">
#          window.gdprAppliesGlobally=true;(function(){function a(e){if(!window.frames[e]){if(document.body&&document.body.firstChild){var t=document.body;var n=document.createElement("iframe");n.style.display="none";n.name=e;n.title=e;t.insertBefore(n,t.firstChild)}
#     else{setTimeout(function(){a(e)},5)}}}function e(n,r,o,c,s){function e(e,t,n,a){if(typeof n!=="function"){return}if(!window[r]){window[r]=[]}var i=false;if(s){i=s(e,t,n)}if(!i){window[r].push({command:e,parameter:t,callback:n,version:a})}}e.stub=true;function t(a){if(!window[n]||window[n].stub!==true){return}if(!a.data){return}
#         var i=typeof a.data==="string";var e;try{e=i?JSON.parse(a.data):a.data}catch(t){return}if(e[o]){var r=e[o];window[n](r.command,r.parameter,function(e,t){var n={};n[c]={returnValue:e,success:t,callId:r.callId};a.source.postMessage(i?JSON.stringify(n):n,"*")},r.version)}}
#         if(typeof window[n]!=="function"){window[n]=e;if(window.addEventListener){window.addEventListener("message",t,false)}else{window.attachEvent("onmessage",t)}}}e("__tcfapi","__tcfapiBuffer","__tcfapiCall","__tcfapiReturn");a("__tcfapiLocator");(function(e){
#         var t=document.createElement("script");t.id="spcloader";t.type="text/javascript";t.async=true;t.src="https://sdk.privacy-center.org/"+e+"/loader.js?target="+document.location.hostname;t.charset="utf-8";var n=document.getElementsByTagName("script")[0];n.parentNode.insertBefore(t,n)})("11ef8ac9-6270-4d5e-8b99-8d6a5bd60059")})();
#         </script>
#         <!-- end Didomi -->
#         <link href="/public/css/property-detail.css?v=ed817" media="screen" rel="stylesheet">
#          <link href="/public/css/property-detail-print.css?v=0fb93" media="print" rel="stylesheet"/>
#          <link href="/public/css/zmaps.css" rel="stylesheet"/>
#          <!-- Google Tag Manager -->
#          <script>
#           (function (w, d, s, l, i) {
#         w[l] = w[l] || [];
#         w[l].push({
#             "gtm.start":
#                 new Date().getTime(), event: "gtm.js"
#         });
#         var f = d.getElementsByTagName(s)[0],
#             j = d.createElement(s), dl = l != "dataLayer" ? "&l=" + l : "";
#         j.async = true;
#         j.src =
#             "https://www.googletagmanager.com/gtm.js?id=" + i + dl;
#         f.parentNode.insertBefore(j, f);
#     })(window, document, "script", "dataLayer", "GTM-5WC6S7");
#          </script>
#          <!-- End Google Tag Manager -->
#          <script crossorigin="anonymous" src="https://browser.sentry-cdn.com/5.1.0/bundle.min.js">
#          </script>
#          <script>
#           Sentry.init({
#                 dsn: 'https://34e49ebb507449d8b3d6c4c135224d82@sentry.zimmo.dev/51',
#                 integrations: [
#                     new Sentry.Integrations.GlobalHandlers({
#                         onerror: false,
#                         onunhandledrejection: false
#                     })
#                 ],
#                 whitelistUrls: [window.location.hostname] // only whitelist errors on zimmo
#             });
#          </script>
#          <!--[if IE]>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.3/html5shiv.js"></script>
# <script type="text/javascript" src="https://cdnjs.cloudflare.com/ajax/libs/json2/20130526/json2.min.js"></script>
# <![endif]-->
#          <script>
#           window.loadFallbackPhoto = function loadFallbackPhoto(img) {
#         return img;
#     }
#          </script>
#          <meta content="Maison" name="cXenseParse:mhu-immo_property_type"/>
#          <meta content="Maison" name="cXenseParse:mhu-immo_property_subtype"/>
#          <meta content="Belgique" name="cXenseParse:mhu-immo_property_country"/>
#          <meta content="à vendre" name="cXenseParse:mhu-immo_property_status"/>
#          <meta content="Couvin" name="cXenseParse:mhu-immo_property_city"/>
#          <meta content="4" name="cXenseParse:mhu-immo_property_bedrooms"/>
#          <meta content="Namur" name="cXenseParse:mhu-immo_property_province"/>
#          <meta content="5660" name="cXenseParse:mhu-immo_property_zipcode"/>
#          <meta content="33153690" name="cXenseParse:mhu-immo_property_adid"/>
#          <meta content="165000.00" name="cXenseParse:mhu-immo_property_price"/>
#          <meta content="100000-199999" name="cXenseParse:mhu-immo_property_price-range"/>
#          <script src="/public/js/modernizr.js?v=ca29d">
#          </script>
#          <!--[if (gte IE 6)&(lte IE 8)]>
#     <script src="/public/js/respond.js?v=9034d"></script>
#     <![endif]-->
#          <meta content="270720989678462" property="fb:app_id">
#           <meta content="Maison à vendre à Couvin € 165.000 (JQLJU) - Immo Les Eaux Vives | Zimmo" property="og:title">
#            <meta content="https://files.zimmo.be/ccdHnWClX9Go09Nl-_QMzs9ffUE=/500x380/filters:image-format(pjpg)/d7/c6/a23a-f989-4ae5-80d6-ae98a93fdb4b/foto_zimmo_a815fe85e1982156d202bae583f41031.jpg" property="og:image">
#             <meta content="https://www.zimmo.be/fr/couvin-5660/a-vendre/maison/JQLJU/" property="og:url">
#              <meta content="Envie d'être en &quot;ville&quot; mais pas trop, besoin d'espace et de verdure, pourquoi ne pas jeter un oeil à cette maison en vente? &lt;br /&gt;
# Maison dans une ru..." property="og:description">
#               <meta content="500" property="og:image:width">
#                <meta content="380" property="og:image:height">
#                 <meta content="property_detail" name="twitter:card"/>
#                 <meta content="@zimmo_be" name="twitter:site"/>
#                 <meta content="@zimmo_be" name="twitter:creator"/>
#                 <meta content="Maison à vendre à Couvin € 165.000 (JQLJU) - Immo Les Eaux Vives | Zimmo" name="twitter:title"/>
#                 <meta content="Envie d'être en &quot;ville&quot; mais pas trop, besoin d'espace et de verdure, pourquoi ne pas jeter un oeil à cette maison en vente? &lt;br /&gt;
# Maison dans une ru..." name="twitter:description"/>
#                 <meta content="https://files.zimmo.be/ccdHnWClX9Go09Nl-_QMzs9ffUE=/500x380/filters:image-format(pjpg)/d7/c6/a23a-f989-4ae5-80d6-ae98a93fdb4b/foto_zimmo_a815fe85e1982156d202bae583f41031.jpg" name="twitter:image"/>
#                 <link href="/public/components.html" rel="import"/>
#                </meta>
#               </meta>
#              </meta>
#             </meta>
#            </meta>
#           </meta>
#          </meta>
#         </link>
#        </link>
#       </link>
#      </link>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body class="default osx property-detail">
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5WC6S7" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <div id="wrapper">
#    <!--[if lte IE 8]>
# <p class="browsehappy">You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade your browser</a> to improve your experience.</p>
# <![endif]-->
#    <div class="ad ad--leaderboard" id="ad_leaderboard-1">
#     <!-- Ad will be rendered here -->
#    </div>
#    <header>
#     <div class="container">
#      <nav id="languageMenu">
#       <ul class="nav nav-pills">
#        <li class="dropdown">
#         <a class="dropdown-label" href="#">
#          fr
#          <b class="caret">
#          </b>
#         </a>
#         <ul class="dropdown-menu pull-right">
#          <li>
#           <a href="https://www.zimmo.be/nl/couvin-5660/te-koop/huis/JQLJU/?search=82d1fed181cf30aaa8408f90d99003d3">
#            Nederlands
#           </a>
#          </li>
#          <li class="disabled">
#           <a href="https://www.zimmo.be/fr/couvin-5660/a-vendre/maison/JQLJU/?search=82d1fed181cf30aaa8408f90d99003d3">
#            Français
#           </a>
#          </li>
#         </ul>
#        </li>
#       </ul>
#      </nav>
#      <form id="frmSearchZimmoCode">
#       <div class="input-append clearfix">
#        <input class="input-mini" id="frmSearchZimmoCode_code" name="code" placeholder="Code Zimmo" type="text"/>
#        <button class="btn btn-xs btn-inverse btn-next-to-input" type="submit">
#         <?xml version="1.0" encoding="utf-8"?>
#         <svg class="svgicon svgicon-search" height="14" version="1.1" viewbox="0 0 35 32" width="14" xmlns="http://www.w3.org/2000/svg">
#          <path d="M32.659 28.889l-5.35-5.068c1.971-2.253 3.097-5.35 3.097-8.447 0-7.602-6.194-13.797-13.797-13.797s-13.515 6.194-13.515 13.797c0 7.602 5.913 13.797 13.515 13.797 3.097 0 6.194-1.126 8.447-3.097l5.068 5.068c0.282 0.282 0.563 0.563 1.126 0.563s0.845-0.282 1.126-0.563c0.282-0.282 0.563-0.563 0.563-1.126s0-0.845-0.282-1.126zM5.91 15.374c0-5.913 4.787-10.699 10.699-10.699s10.981 4.787 10.981 10.699c0 5.913-4.787 10.699-10.699 10.699s-10.981-4.787-10.981-10.699z">
#          </path>
#         </svg>
#        </button>
#       </div>
#      </form>
#      <ul class="breadcrumb">
#       <li>
#        <a class="grey" data-ga="Home,click,Breadcrumb" href="/fr/">
#         <!-- Generated by IcoMoon.io -->
#         <svg class="svgicon svgicon-house" height="14" version="1.1" viewbox="0 0 38 32" width="14" xmlns="http://www.w3.org/2000/svg">
#          <path d="M35.491 16.418l-15.418-14.255c-0.582-0.291-1.164-0.291-1.745 0l-15.418 14.255c-0.291 0.291-0.291 1.164 0 1.455s0.582 0.582 0.873 0.582c0.291 0 0.582 0 0.873-0.291l1.164-1.164v13.673c0 0.582 0.582 1.164 1.164 1.164h24.436c0.582 0 1.164-0.582 1.164-1.164v-13.673l1.164 0.873c0.582 0.582 1.164 0.582 1.745 0 0.291-0.291 0.291-0.582 0.291-0.873s0-0.582-0.291-0.582zM21.236 29.8h-4.073v-6.982h4.073v6.982zM23.855 29.8v-8.436c0-0.582-0.582-1.164-1.164-1.164h-6.691c-0.873 0-1.164 0.582-1.164 1.164v8.145h-6.691v-14.545l11.055-10.182 10.764 10.182v14.836h-6.109z" fill="#999">
#          </path>
#         </svg>
#        </a>
#       </li>
#       <li>
#        <a href="https://www.zimmo.be/fr/couvin-5660/a-vendre/">
#         à vendre à Couvin
#        </a>
#       </li>
#       <li>
#        <a href="https://www.zimmo.be/fr/couvin-5660/a-vendre/maison/">
#         maison à vendre à Couvin
#        </a>
#       </li>
#       <li class="active">
#        JQLJU
#       </li>
#      </ul>
#      <div id="mainLogo">
#       <a class="logo-home logo-fr" href="/fr/">
#       </a>
#       <p class="show-on-print print-logo">
#        <img alt="Zimmo" class="img-responsive" src="/public/images/header/zimmo-small-1x.png?v=a2a63" style="width:184px;"/>
#       </p>
#      </div>
#      <div id="nationalInternational">
#       <span class="selected">
#        Belgique
#       </span>
#       <a href="https://www.zimmo.be/international/fr">
#        International
#       </a>
#      </div>
#      <nav id="headerMenu">
#       <div class="favorites-menu">
#        <ul class="nav nav-pills">
#         <li>
#          <a class="results-favorites" data-ga="Favorites page,click,Header icon" href="/fr/biens/favori/">
#           <?xml version="1.0" encoding="utf-8"?>
#           <!-- Generator: Adobe Illustrator 22.0.1, SVG Export Plug-In . SVG Version: 6.00 Build 0)  -->
#           <svg class="svgicon svgicon-star" height="14" id="Layer_1" style="enable-background:new 0 0 16 15;" version="1.1" viewbox="0 0 16 15" width="14" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
#            <style type="text/css">
#             .st0{fill:#ffb000;}
#            </style>
#            <g id="Menu" transform="translate(-1345.000000, -48.000000)">
#             <g id="Group-6" transform="translate(-37.000000, -1.000000)">
#              <g id="Group-9" transform="translate(1383.392578, 47.000000)">
#               <g id="tt">
#                <path class="st0" d="M10.6,16.5c-0.2,0-0.5-0.1-0.8-0.2l-3-1.6l-3,1.6c-0.5,0.3-1.1,0.3-1.5,0c-0.4-0.3-0.6-0.8-0.4-1.4l0.6-3.4
# 					L0,9.2c-0.4-0.4-0.6-0.9-0.5-1.4C-0.3,7.3,0.1,7,0.7,6.9l3.4-0.5l1.5-3.1c0.5-1.1,1.8-1.1,2.4,0l1.5,3.1l3.4,0.5
# 					c0.6,0.1,1,0.4,1.2,0.9c0.1,0.5,0,1-0.5,1.4l-2.5,2.4l0.6,3.4c0.1,0.6-0.1,1.1-0.5,1.4C11.1,16.4,10.9,16.5,10.6,16.5z M1,8.2
# 					l2.4,2.4c0.3,0.3,0.4,0.8,0.4,1.2l-0.6,3.4l3-1.6c0.4-0.2,0.9-0.2,1.2,0l3,1.6l-0.6-3.4c-0.1-0.4,0.1-0.9,0.4-1.2l2.4-2.4
# 					L9.3,7.7C8.9,7.7,8.5,7.4,8.3,7L6.8,4L5.3,7c-0.2,0.4-0.6,0.7-1,0.7L1,8.2z">
#                </path>
#               </g>
#              </g>
#             </g>
#            </g>
#           </svg>
#           <span class="value">
#            0
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="mijnzimmo-menu">
#        <div class="menu-prefix">
#         <!-- Generated by IcoMoon.io -->
#         <svg class="svgicon svgicon-person" height="14" version="1.1" viewbox="0 0 30 32" width="14" xmlns="http://www.w3.org/2000/svg">
#          <path d="M15.297 0.457c-4.114 0-7.543 3.429-7.543 7.543s3.429 7.543 7.543 7.543c4.114 0 7.543-3.429 7.543-7.543s-3.429-7.543-7.543-7.543zM19.869 8c0 2.514-2.057 4.571-4.571 4.571s-4.571-2.057-4.571-4.571 2.057-4.571 4.571-4.571c2.514 0 4.571 2.057 4.571 4.571z" fill="#999">
#          </path>
#          <path d="M15.297 18.286c-7.543 0-13.943 5.486-13.943 11.886 0 0.914 0.686 1.371 1.6 1.371s1.6-0.686 1.6-1.371c0-4.8 4.8-8.914 10.743-8.914s10.743 3.886 10.743 8.914c0 0.914 0.686 1.371 1.6 1.371s1.6-0.686 1.6-1.371c0-6.4-6.171-11.886-13.943-11.886z" fill="#999">
#          </path>
#         </svg>
#         Mon Zimmo
#        </div>
#        <ul class="nav nav-pills mouse-over-menu">
#         <li class="dpd-user user-login-link">
#          <a href="https://www.zimmo.be/fr/monzimmo/login/">
#           <span class="login-link">
#            Se connecter
#           </span>
#          </a>
#         </li>
#         <li class="dpd-user user-register-link">
#          <a href="https://www.zimmo.be/fr/monzimmo/enregistrer/">
#           <span class="login-link">
#            S'enregistrer
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <ul class="nav nav-pills header-menu mouse-over-menu">
#        <li class="new_property_link">
#         <a href="https://www.zimmo.be/fr/page/vendre-votre-bien/">
#          <span>
#           Publiez
#          </span>
#          votre bien
#         </a>
#        </li>
#        <li class="dropdown">
#         <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#          Plus
#          <b class="caret">
#          </b>
#         </a>
#         <ul class="dropdown-menu pull-right">
#          <li>
#           <a href="https://www.zimmo.be/fr/page/publicite/">
#            Publicité
#           </a>
#          </li>
#          <li>
#           <a href="https://www.zimmo.be/blog/?lang=fr" target="_blank">
#            Blog
#           </a>
#          </li>
#          <li>
#           <a href="https://www.zimmo.be/fr/simulation-pr%C3%AAt-hypoth%C3%A9caire/">
#            Simulateur de prêt
#           </a>
#          </li>
#          <li>
#           <a href="https://www.zimmo.be/fr/page/biens-a-flirter/">
#            A flirter
#           </a>
#          </li>
#          <li>
#           <a href="https://www.zimmo.be/fr/page/je_suis_professionnel/">
#            Zimmo for Business pour les agents immobiliers
#           </a>
#          </li>
#          <li>
#           <a href="https://www.zimmo.be/fr/professionel-immobilier/">
#            Chercher un professionnel de l'immobilier
#           </a>
#          </li>
#          <li>
#           <a href="https://www.zimmo.be/fr/questions-frequemment-posees/">
#            Questions fréquemment posées
#           </a>
#          </li>
#          <li>
#           <a href="https://www.zimmo.be/fr/page/a_propos/">
#            À propos de Zimmo
#           </a>
#          </li>
#          <li>
#           <a href="https://www.zimmo.be/fr/jobs/">
#            Travailler chez Zimmo
#           </a>
#          </li>
#          <li>
#           <a href="https://www.zimmo.be/fr/page/contact/">
#            Contact
#           </a>
#          </li>
#         </ul>
#        </li>
#       </ul>
#      </nav>
#      <div id="btnHeaderMenuContainer">
#       <button class="btn btn-primary" id="btnHeaderMenu">
#        <?xml version="1.0" encoding="UTF-8"?>
#        <svg class="svgicon svgicon-menu" height="14" version="1.1" viewbox="0 0 10 10" width="14" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#         <g fill="none" fill-rule="evenodd" id="01-d-mobile-aanbod-1" stroke="none" stroke-="" transform="translate(-297.000000, -63.000000)">
#          <g fill="#FFFFFF" id="Group" transform="translate(296.500000, 61.500000)">
#           <path d="M0.484741211,2.71672071 C0.484741211,2.34850113 0.788824201,2.05000019 1.14202172,2.05000019 L8.96682455,2.05000019 C9.32983055,2.05000019 9.62410506,2.34593397 9.62410506,2.71672071 C9.62410506,3.08494028 9.32002207,3.38344122 8.96682455,3.38344122 L1.14202172,3.38344122 C0.779015719,3.38344122 0.484741211,3.08750744 0.484741211,2.71672071 Z M0.484741211,6.5 C0.484741211,6.13178043 0.788824201,5.83327949 1.14202172,5.83327949 L8.96682455,5.83327949 C9.32983055,5.83327949 9.62410506,6.12921327 9.62410506,6.5 C9.62410506,6.86821957 9.32002207,7.16672051 8.96682455,7.16672051 L1.14202172,7.16672051 C0.779015719,7.16672051 0.484741211,6.87078673 0.484741211,6.5 Z M0.484741211,10.2832793 C0.484741211,9.91505972 0.788824201,9.61655878 1.14202172,9.61655878 L8.96682455,9.61655878 C9.32983055,9.61655878 9.62410506,9.91249256 9.62410506,10.2832793 C9.62410506,10.6514989 9.32002207,10.9499998 8.96682455,10.9499998 L1.14202172,10.9499998 C0.779015719,10.9499998 0.484741211,10.654066 0.484741211,10.2832793 Z" id="menu">
#           </path>
#          </g>
#         </g>
#        </svg>
#        Menu
#       </button>
#      </div>
#     </div>
#    </header>
#    <div class="navbar navbar-default" id="mainMenu" role="navigation">
#     <div class="container">
#      <ul class="nav navbar-nav">
#       <li>
#        <a data-ga="Orange menu,click,A vendre" href='javascript:app.openAdvancedSearchMenu({status:"1"},null, {titleKey: "menu.properties.search_for_sale"})'>
#         A vendre
#        </a>
#       </li>
#       <li>
#        <a data-ga="Orange menu,click,A louer" href='javascript:app.openAdvancedSearchMenu({status:"2"},null, {titleKey: "menu.properties.search_for_rent"})'>
#         A louer
#        </a>
#       </li>
#       <li>
#        <a data-ga="Orange menu,click,Projets neufs" href='javascript:app.openAdvancedSearchMenu({newConstructionOnly:true,projectsOnly:true},null, {titleKey: "menu.properties.search_new_projects"})'>
#         Projets neufs
#        </a>
#       </li>
#       <li>
#        <a data-ga="Orange menu,click,Biens professionnels" href='javascript:app.openAdvancedSearchMenu({type: ["4"]},null, {titleKey: "menu.properties.search_commercial_real_estate", commercial: true})'>
#         Biens professionnels
#        </a>
#       </li>
#       <li>
#        <a data-ga="Orange menu,click,Immeubles de rapport" href='javascript:app.openAdvancedSearchMenu({filterInvestments: true},null, {titleKey: "menu.properties.search_investment_properties"})'>
#         Immeubles de rapport
#        </a>
#       </li>
#       <li>
#        <a data-ga="Orange menu,click,Indicateur de prix" href="https://www.zimmo.be/fr/indicateur-de-prix/">
#         Indicateur de prix
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div class="content">
#     <a class="feedback-btn" data-ga="Feedback,click,Side button" href="javascript:app.openFeedback('Feedback');void(0);">
#      <span>
#       Feedback
#      </span>
#     </a>
#     <div class="hero-unit">
#      <div class="container">
#       <h1 class="pand-title">
#        Maison à vendre à Couvin pour € 165.000 avec 4 chambres
#        <div class="zimmo-code">
#         (Code Zimmo: JQLJU)
#        </div>
#       </h1>
#      </div>
#     </div>
#     <div class="hero-unit tabs tabs-collapse">
#      <div class="container">
#       <div class="tabs-right">
#        <ul class="tabs">
#         <li>
#          <a class="btn back" data-ga="Back button,click,Detail page" data-placement="bottom" data-toggle="tooltip" href="javascript:history.go(-1);" title="Retour à la page précédente">
#           <i class="zf-icon icon-list-gallery-left">
#           </i>
#           <span>
#            Retour aux résultats
#           </span>
#          </a>
#         </li>
#         <li>
#          <a class="btn save-property" data-ga="Favorite,enable (Regular), Detail fixed header" data-placement="bottom" data-toggle="tooltip" href="javascript:void(0)" title="Ajouter à vos favoris">
#           <?xml version="1.0" encoding="utf-8"?>
#           <!-- Generator: Adobe Illustrator 22.0.1, SVG Export Plug-In . SVG Version: 6.00 Build 0)  -->
#           <svg class="svgicon svgicon-star-full" height="14" style="enable-background:new 0 0 16 15;" version="1.1" viewbox="0 0 16 15" width="14" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
#            <style type="text/css">
#             <![CDATA[
# 		.star-full0{display:none;}
# 		.star-full1{display:inline;}
# 		.star-full2{fill:#999999;}
# 	]]>
#            </style>
#            <g class="star-full0" id="Layer_1">
#             <g id="Menu" transform="translate(-1345.000000, -48.000000)">
#              <g class="star-full1" id="Group-6" transform="translate(-37.000000, -1.000000)">
#               <g id="Group-9" transform="translate(1383.392578, 47.000000)">
#                <g id="tt">
#                 <path class="star-full2" d="M10.6,16.5c-0.2,0-0.5-0.1-0.8-0.2l-3-1.6l-3,1.6c-0.5,0.3-1.1,0.3-1.5,0s-0.6-0.8-0.4-1.4l0.6-3.4L0,9.2
# 						c-0.4-0.4-0.6-0.9-0.5-1.4C-0.3,7.3,0.1,7,0.7,6.9l3.4-0.5l1.5-3.1c0.8-1.7,1.6-1.7,2.4,0l1.5,3.1l3.4,0.5
# 						c0.6,0.1,1.3,0.2,1.5,0.7c0.1,0.5-0.3,1.2-0.8,1.6l-2.5,2.4l0.6,3.4c0.1,0.6-0.1,1.1-0.5,1.4C11,16.5,10.9,16.5,10.6,16.5z">
#                 </path>
#                </g>
#               </g>
#              </g>
#             </g>
#            </g>
#            <g id="Layer_2">
#             <path class="star-full2" d="M5.5,4.4l1.7-3.8c0.3-0.8,1.4-0.8,1.8,0l1.9,3.8l4.4,0.7c0.7,0.1,1,1,0.5,1.5l-3.2,3l0.8,4.5
# 		c0.1,0.6-0.5,1-1,0.7l-4.1-2.2l-3.9,2.2C3.6,15.2,2.9,14.7,3,14l0.9-4.5L0.2,6.2c-0.4-0.4-0.2-1,0.3-1.1L5.5,4.4z">
#             </path>
#            </g>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a class="btn share-btn" data-ga="Share button,click (Regular),Detail page fixed header" data-gemeente="Couvin" data-pand-img="https://files.zimmo.be/ccdHnWClX9Go09Nl-_QMzs9ffUE=/500x380/filters:image-format(pjpg)/d7/c6/a23a-f989-4ae5-80d6-ae98a93fdb4b/foto_zimmo_a815fe85e1982156d202bae583f41031.jpg" data-pand-title="" data-pand-url="https://www.zimmo.be/fr/couvin-5660/a-vendre/maison/JQLJU/" data-tooltip-title="Partager avec des amis" href="javascript:void(0);">
#           <?xml version="1.0" encoding="utf-8"?>
#           <!-- Generator: Adobe Illustrator 22.0.1, SVG Export Plug-In . SVG Version: 6.00 Build 0)  -->
#           <svg class="svgicon svgicon-share" height="14" id="Layer_1" style="enable-background:new 0 0 13 16;" version="1.1" viewbox="0 0 13 16" width="14" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
#            <g id="_x30_2-detail" transform="translate(-1310.000000, -288.000000)">
#             <path d="M1320.4,288c-1.4,0-2.6,1.2-2.6,2.7c0,0.3,0,0.5,0.1,0.7l-3.6,2.5c-0.4-0.4-1-0.6-1.6-0.6
# 		c-1.4,0-2.6,1.2-2.6,2.7s1.2,2.7,2.6,2.7c0.6,0,1.2-0.2,1.6-0.6l3.6,2.5c-0.1,0.2-0.1,0.5-0.1,0.8c0,1.5,1.2,2.7,2.6,2.7
# 		s2.6-1.2,2.6-2.7c0-1.5-1.2-2.7-2.6-2.7c-0.8,0-1.5,0.4-2,1l-3.4-2.4c0.2-0.4,0.3-0.8,0.3-1.3c0-0.5-0.1-0.9-0.3-1.3
# 		c1.2-0.8,2.1-1.6,3.4-2.4c0.5,0.6,1.2,1,2,1c1.4,0,2.6-1.2,2.6-2.7C1323,289.2,1321.8,288,1320.4,288z" id="Shape">
#             </path>
#            </g>
#           </svg>
#          </a>
#         </li>
#         <li>
#          <a class="contact-seller btn" data-ga="Contact advertiser,click (Regular),Detail page fixed header" data-id="general" data-placement="bottom" data-toggle="tooltip" href="javascript:void(0);" title="Contacter vendeur">
#           <?xml version="1.0" encoding="utf-8"?>
#           <!-- Generator: Adobe Illustrator 22.0.1, SVG Export Plug-In . SVG Version: 6.00 Build 0)  -->
#           <svg class="svgicon svgicon-envelope" height="14" id="Layer_1" style="enable-background:new 0 0 16 12;" version="1.1" viewbox="0 0 16 12" width="14" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
#            <g>
#             <path d="M8,7.8L0,2.4v8.5C0,11.5,0.5,12,1.1,12h13.8c0.6,0,1.1-0.5,1.1-1.1V2.5L8,7.8z">
#             </path>
#             <path d="M8,6.3L15.9,1c-0.1-0.5-0.5-1-1.1-1H1.1C0.5,0,0.1,0.4,0,1L8,6.3z">
#             </path>
#            </g>
#           </svg>
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="tabs-left">
#        <a data-ga="Home,click,Fixed header on detail page" href="/fr/" id="tabLogo">
#         <img src="/public/images/fixed-tabs-icon.png?v=b8400"/>
#        </a>
#        <p class="current-active-tab">
#         <span class="current-tab-name">
#          Détails
#         </span>
#         <span class="zf-icon icon-chevron-small-down">
#         </span>
#        </p>
#        <ul class="tabs detail-page-tabs" id="viewtype">
#         <li class="active" data-tab="detail">
#          <a class="btn btn-default" href="#/detail">
#           Détails
#          </a>
#         </li>
#         <li class="website" data-tab="website">
#          <a class="btn btn-default source-website" href="https://immoleseauxvives.be/bien/2707" target="_blank">
#           Site web du vendeur
#          </a>
#         </li>
#         <li data-tab="nieuws">
#          <a class="btn btn-default" href="#/nieuws">
#           À propos de Couvin
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <div class="mobile-buttons">
#      <div class="row">
#       <div class="col-xs-6 phone-btn">
#        <a class="btn btn-success phone-number-link" data-origin="sticky-button" href="javascript:void(0);">
#         <?xml version="1.0" encoding="utf-8"?>
#         <!-- Generator: Adobe Illustrator 24.1.0, SVG Export Plug-In . SVG Version: 6.00 Build 0)  -->
#         <svg class="svgicon svgicon-phone-outline" height="17" id="Layer_1" style="enable-background:new 0 0 18 17;" version="1.1" viewbox="0 0 18 17" width="18" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
#          <path d="M15.7,13.7c-0.1,0.1-0.3,0.3-0.4,0.4c-0.3,0.3-0.6,0.5-0.8,0.8
# 	c-0.3,0.3-0.6,0.4-1,0.4c0,0-0.1,0-0.1,0c-0.9,0-1.7-0.3-2.8-0.8c-2.1-1-3.9-2.3-5.5-4.1C3.8,9,2.9,7.6,2.3,6.2
# 	C2,5.3,1.9,4.7,1.9,4.1c0-0.3,0.1-0.5,0.3-0.7c0.3-0.3,0.5-0.5,0.8-0.8c0.2-0.2,0.3-0.3,0.5-0.5C3.7,2,3.8,2,3.8,2
# 	c0,0,0.1,0,0.2,0.1c0.2,0.2,0.5,0.4,0.7,0.7L5,3.1c0.2,0.2,0.3,0.3,0.5,0.5c0.2,0.2,0.3,0.3,0.5,0.5c0.2,0.2,0.2,0.2,0,0.4L5.9,4.7
# 	C5.5,5,5.2,5.4,4.8,5.7C4.4,6.1,4.3,6.7,4.5,7.2c0.3,0.7,0.7,1.3,1.3,2c1.1,1.3,2.3,2.3,3.5,3.1c0.2,0.1,0.4,0.2,0.6,0.3
# 	c0.1,0,0.2,0.1,0.3,0.1c0.2,0.1,0.4,0.2,0.7,0.2c0.3,0,0.6-0.1,1-0.4c0.4-0.4,0.8-0.8,1.3-1.2c0.1-0.1,0.2-0.1,0.2-0.1
# 	c0,0,0.1,0,0.2,0.1c0.7,0.7,1.4,1.3,2.1,2C15.8,13.4,15.9,13.5,15.7,13.7 M14.3,10.5c-0.3-0.3-0.6-0.4-0.9-0.4
# 	c-0.3,0-0.6,0.1-0.9,0.4c-0.4,0.4-0.9,0.8-1.3,1.3c-0.1,0.1-0.1,0.1-0.2,0.1c0,0-0.1,0-0.2,0c-0.3-0.1-0.6-0.3-0.9-0.4
# 	c-1.3-0.8-2.3-1.7-3.3-2.8C6.2,8,5.8,7.4,5.5,6.8c-0.1-0.1,0-0.2,0.1-0.3C6,6.1,6.4,5.6,6.8,5.2c0.6-0.6,0.6-1.3,0-1.8
# 	c-0.3-0.3-0.7-0.7-1-1c-0.4-0.3-0.7-0.7-1.1-1C4.4,1.1,4.1,1,3.8,1C3.5,1,3.1,1.1,2.9,1.4C2.4,1.8,2,2.2,1.5,2.6
# 	C1.1,3,0.9,3.5,0.9,4C0.8,4.9,1,5.7,1.3,6.5C2,8.2,3,9.7,4.2,11c1.6,1.8,3.6,3.3,5.8,4.3c1,0.5,2.1,0.8,3.2,0.9c0.1,0,0.1,0,0.2,0
# 	c0.7,0,1.3-0.2,1.8-0.7c0.4-0.4,0.8-0.8,1.2-1.2c0.6-0.6,0.6-1.3,0-1.8C15.7,11.9,15,11.2,14.3,10.5" style="fill-rule:evenodd;clip-rule:evenodd;">
#          </path>
#          <path d="M9.2,4.5c1.8,0.7,3.2,2.1,4,3.8c0.1,0.2,0.3,0.3,0.5,0.3
# 	c0.1,0,0.1,0,0.2,0c0.3-0.1,0.4-0.4,0.3-0.7c-0.9-2-2.5-3.5-4.6-4.4C9.3,3.5,9,3.6,8.9,3.8C8.8,4.1,8.9,4.4,9.2,4.5" style="fill-rule:evenodd;clip-rule:evenodd;">
#          </path>
#          <path d="M17.1,7.6c-1.4-3.1-4-5.6-7.2-6.9c-0.3-0.1-0.6,0-0.7,0.3
# 	c-0.1,0.3,0,0.6,0.3,0.7c3,1.2,5.4,3.4,6.7,6.3c0.1,0.2,0.3,0.3,0.5,0.3c0.1,0,0.1,0,0.2,0C17.1,8.2,17.2,7.9,17.1,7.6" style="fill-rule:evenodd;clip-rule:evenodd;">
#          </path>
#         </svg>
#         Téléphoner
#        </a>
#       </div>
#       <div class="col-xs-6 mail-btn">
#        <a class="btn btn-primary contact-seller" data-ga="Contact advertiser,click,Detailpagina - Advertiser block sticky" data-id="mobile_button" href="javascript:void(0);">
#         <?xml version="1.0" encoding="utf-8"?>
#         <!-- Generator: Adobe Illustrator 24.1.0, SVG Export Plug-In . SVG Version: 6.00 Build 0)  -->
#         <svg class="svgicon svgicon-envelope-outline" height="18" id="Layer_1" style="enable-background:new 0 0 18 13;" version="1.1" viewbox="0 0 18 13" width="13" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
#          <path d="M16.9,10c0,0.2,0,0.4-0.1,0.6l-4.9-4.6l4.6-3.8
# 	c0,0,0.1-0.1,0.1-0.1c0.1,0.2,0.2,0.5,0.2,0.8V10z M15.2,11.7H2.8c-0.3,0-0.5-0.1-0.7-0.2l4.8-4.6l1.6,1.3c0.1,0.1,0.2,0.1,0.4,0.1
# 	c0.1,0,0.3,0,0.4-0.1L11,6.8l4.9,4.7C15.7,11.6,15.5,11.7,15.2,11.7L15.2,11.7z M1.1,10V3c0-0.2,0-0.4,0.1-0.6L6,6.2l-4.7,4.5
# 	C1.2,10.5,1.1,10.3,1.1,10L1.1,10z M2.8,1.3h12.4c0.2,0,0.4,0,0.6,0.1L8.9,7.1L2,1.5C2.3,1.4,2.5,1.3,2.8,1.3L2.8,1.3z M15.2,0.2
# 	H2.8C1.3,0.2,0,1.5,0,3V10c0,1.5,1.3,2.7,2.8,2.7h12.4c1.5,0,2.8-1.2,2.8-2.7V3C18,1.5,16.7,0.2,15.2,0.2L15.2,0.2z" style="fill-rule:evenodd;clip-rule:evenodd;">
#          </path>
#         </svg>
#         Par e-mail
#        </a>
#       </div>
#      </div>
#     </div>
#     <section id="tab-detail">
#      <div class="tab-submenu">
#       <div class="container">
#        <ul>
#         <li class="images">
#          <a class="showPictures active" href="#images">
#           Photos
#          </a>
#          <span class="menu-divider">
#           |
#          </span>
#         </li>
#         <li>
#          <a class="tabmenu-item" href="#main-features">
#           Caractéristiques principales
#          </a>
#          <span class="menu-divider">
#           |
#          </span>
#         </li>
#         <li>
#          <a class="tabmenu-item tabmenu-description" href="#description">
#           Description
#          </a>
#          <span class="menu-divider">
#           |
#          </span>
#         </li>
#         <li>
#          <a class="tabmenu-item" href="#repayment">
#           Remboursement mensuel
#          </a>
#          <span class="menu-divider">
#           |
#          </span>
#         </li>
#         <li>
#          <a class="tabmenu-item" href="#section-costs-monthly">
#           Estimation des frais
#          </a>
#          <span class="menu-divider">
#           |
#          </span>
#         </li>
#         <li>
#          <a class="tabmenu-item" href="#section-zmv">
#           Comparaison
#          </a>
#          <span class="menu-divider">
#           |
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="container main-container">
#       <div class="pand-detail">
#        <div class="align-block-left" id="slider-container">
#         <div class="top-preview-container" id="images">
#          <p class="main-image show-on-print">
#           <img alt="                                        Maison à vendre à Couvin, € 165.000
# " src="https://files.zimmo.be/ccdHnWClX9Go09Nl-_QMzs9ffUE=/500x380/filters:image-format(pjpg)/d7/c6/a23a-f989-4ae5-80d6-ae98a93fdb4b/foto_zimmo_a815fe85e1982156d202bae583f41031.jpg"/>
#          </p>
#          <div class="slider-box-container">
#           <div class="slider-mobile">
#            <div class="slider-mobile-list">
#            </div>
#            <img alt="                                        Maison à vendre à Couvin, € 165.000
# " class="thumbnail main-image" data-index="1" src="https://files.zimmo.be/ccdHnWClX9Go09Nl-_QMzs9ffUE=/500x380/filters:image-format(pjpg)/d7/c6/a23a-f989-4ae5-80d6-ae98a93fdb4b/foto_zimmo_a815fe85e1982156d202bae583f41031.jpg">
#             <div class="slider-count">
#              <?xml version="1.0" encoding="utf-8"?>
#              <!-- Generator: Adobe Illustrator 24.1.0, SVG Export Plug-In . SVG Version: 6.00 Build 0)  -->
#              <svg class="svgicon svgicon-gallery" height="16" id="Layer_1" style="enable-background:new 0 0 19 17;" version="1.1" viewbox="0 0 19 17" width="18" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
#               <g>
#                <path d="M9.5,6.9c-0.9,0-1.6,0.7-1.6,1.6c0,0.9,0.7,1.6,1.6,1.6c0.9,0,1.6-0.7,1.6-1.6S10.4,6.9,9.5,6.9z M9.5,9.4
# 		C9,9.4,8.6,9,8.6,8.5S9,7.6,9.5,7.6l0,0c0.5,0,0.9,0.4,0.9,0.9S10,9.4,9.5,9.4z" id="Shape">
#                </path>
#                <path d="M17.1,1.8L4.9,0.4c-0.5-0.1-1,0.1-1.3,0.4C3.2,1.1,3,1.5,2.9,1.9L2.7,3.8H2c-1,0-1.7,0.9-1.7,1.9v9.2
# 		c0,0.9,0.7,1.7,1.7,1.8c0,0,0,0,0.1,0h12.3c1,0,1.9-0.8,1.9-1.8v-0.4c0.3-0.1,0.6-0.2,0.8-0.4c0.4-0.3,0.6-0.7,0.6-1.2l1-9.1
# 		C18.8,2.8,18.1,1.9,17.1,1.8z M15.3,14.9c0,0.5-0.5,0.9-1,0.9H2c-0.4,0-0.8-0.3-0.8-0.8c0,0,0,0,0-0.1v-1.7l3.5-2.6
# 		c0.4-0.3,1-0.3,1.4,0.1l2.4,2.2c0.4,0.3,0.8,0.5,1.3,0.5c0.4,0,0.7-0.1,1.1-0.3l4.4-2.6V14.9L15.3,14.9z M15.3,9.4l-4.9,2.9
# 		c-0.4,0.2-0.9,0.2-1.3-0.1L6.6,10C5.9,9.4,4.9,9.4,4.1,9.9l-3,2.2V5.7c0-0.5,0.3-1,0.8-1h12.3c0.5,0,1,0.4,1,1V9.4L15.3,9.4z
# 		 M17.8,3.7C17.8,3.7,17.8,3.7,17.8,3.7l-1.1,9.1c0,0.2-0.1,0.5-0.3,0.6c-0.1,0.1-0.3,0.1-0.3,0.2V5.7c0-1-0.9-1.8-1.9-1.9H3.6
# 		L3.8,2c0-0.2,0.2-0.4,0.3-0.6c0.2-0.1,0.4-0.2,0.7-0.2L17,2.7C17.5,2.7,17.9,3.2,17.8,3.7z" id="Shape_1_">
#                </path>
#               </g>
#              </svg>
#              <span class="slider-count__number">
#               1
#              </span>
#              /
#              <span class="slider-count_total">
#               24
#              </span>
#             </div>
#            </img>
#           </div>
#           <div class="slider-container">
#            <div class="slider-placeholder">
#             <img alt="                                        Maison à vendre à Couvin, € 165.000
# " class="main-image triggerSlider" data-index="1" src="https://files.zimmo.be/ccdHnWClX9Go09Nl-_QMzs9ffUE=/500x380/filters:image-format(pjpg)/d7/c6/a23a-f989-4ae5-80d6-ae98a93fdb4b/foto_zimmo_a815fe85e1982156d202bae583f41031.jpg"/>
#            </div>
#            <div class="slider" id="detail-slider">
#            </div>
#           </div>
#          </div>
#          <div class="liggingsplan-container">
#           <div id="detail-map">
#           </div>
#          </div>
#         </div>
#         <nav class="navbar-actions no-streetview">
#          <ul class="nav">
#           <li class="active images">
#            <a data-mode="fotos" href="#">
#             <span class="total-slides-count">
#             </span>
#             Photos
#            </a>
#           </li>
#           <li class="">
#            <a data-mode="liggingsplan" href="#">
#             Plan de situation
#            </a>
#           </li>
#          </ul>
#         </nav>
#        </div>
#        <div class="contact-block align-block-right">
#         <div id="sidebar-advertiser-container">
#          <div class="contact-gegevens-block contact-block-sidebar">
#           <div class="contact-block-inner">
#            <div class="contact-header align-contact-block-left">
#             <p class="contact-title">
#              Demander plus d'info ou une visite
#             </p>
#             <div class="contact-title">
#              <h4>
#               Immo Les Eaux Vives
#              </h4>
#             </div>
#             <div class="contact-logo">
#              <a class="view-seller" href="https://www.zimmo.be/fr/agence-immobiliere/couvin-5660/immo-les-eaux-vives-37225/" title="">
#               <img alt="Immo Les Eaux Vives" src="https://images.zimmo.be/logos/L_11801_fr.gif"/>
#              </a>
#             </div>
#            </div>
#            <div class="advertiser-form align-contact-block-right hide-on-print" id="advertiser-form-sidebar">
#            </div>
#            <div class="contact-phone align-contact-block-left">
#             <p class="contact-nr show-on-print">
#              +32 (0)60 30 02 36
#              <br/>
#             </p>
#             <p class="contact-nr-collection">
#              <?xml version="1.0" encoding="utf-8"?>
#              <!-- Generator: Adobe Illustrator 24.1.0, SVG Export Plug-In . SVG Version: 6.00 Build 0)  -->
#              <svg class="svgicon svgicon-phone-outline" height="17" id="Layer_1" style="enable-background:new 0 0 18 17;" version="1.1" viewbox="0 0 18 17" width="18" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
#               <path d="M15.7,13.7c-0.1,0.1-0.3,0.3-0.4,0.4c-0.3,0.3-0.6,0.5-0.8,0.8
# 	c-0.3,0.3-0.6,0.4-1,0.4c0,0-0.1,0-0.1,0c-0.9,0-1.7-0.3-2.8-0.8c-2.1-1-3.9-2.3-5.5-4.1C3.8,9,2.9,7.6,2.3,6.2
# 	C2,5.3,1.9,4.7,1.9,4.1c0-0.3,0.1-0.5,0.3-0.7c0.3-0.3,0.5-0.5,0.8-0.8c0.2-0.2,0.3-0.3,0.5-0.5C3.7,2,3.8,2,3.8,2
# 	c0,0,0.1,0,0.2,0.1c0.2,0.2,0.5,0.4,0.7,0.7L5,3.1c0.2,0.2,0.3,0.3,0.5,0.5c0.2,0.2,0.3,0.3,0.5,0.5c0.2,0.2,0.2,0.2,0,0.4L5.9,4.7
# 	C5.5,5,5.2,5.4,4.8,5.7C4.4,6.1,4.3,6.7,4.5,7.2c0.3,0.7,0.7,1.3,1.3,2c1.1,1.3,2.3,2.3,3.5,3.1c0.2,0.1,0.4,0.2,0.6,0.3
# 	c0.1,0,0.2,0.1,0.3,0.1c0.2,0.1,0.4,0.2,0.7,0.2c0.3,0,0.6-0.1,1-0.4c0.4-0.4,0.8-0.8,1.3-1.2c0.1-0.1,0.2-0.1,0.2-0.1
# 	c0,0,0.1,0,0.2,0.1c0.7,0.7,1.4,1.3,2.1,2C15.8,13.4,15.9,13.5,15.7,13.7 M14.3,10.5c-0.3-0.3-0.6-0.4-0.9-0.4
# 	c-0.3,0-0.6,0.1-0.9,0.4c-0.4,0.4-0.9,0.8-1.3,1.3c-0.1,0.1-0.1,0.1-0.2,0.1c0,0-0.1,0-0.2,0c-0.3-0.1-0.6-0.3-0.9-0.4
# 	c-1.3-0.8-2.3-1.7-3.3-2.8C6.2,8,5.8,7.4,5.5,6.8c-0.1-0.1,0-0.2,0.1-0.3C6,6.1,6.4,5.6,6.8,5.2c0.6-0.6,0.6-1.3,0-1.8
# 	c-0.3-0.3-0.7-0.7-1-1c-0.4-0.3-0.7-0.7-1.1-1C4.4,1.1,4.1,1,3.8,1C3.5,1,3.1,1.1,2.9,1.4C2.4,1.8,2,2.2,1.5,2.6
# 	C1.1,3,0.9,3.5,0.9,4C0.8,4.9,1,5.7,1.3,6.5C2,8.2,3,9.7,4.2,11c1.6,1.8,3.6,3.3,5.8,4.3c1,0.5,2.1,0.8,3.2,0.9c0.1,0,0.1,0,0.2,0
# 	c0.7,0,1.3-0.2,1.8-0.7c0.4-0.4,0.8-0.8,1.2-1.2c0.6-0.6,0.6-1.3,0-1.8C15.7,11.9,15,11.2,14.3,10.5" style="fill-rule:evenodd;clip-rule:evenodd;">
#               </path>
#               <path d="M9.2,4.5c1.8,0.7,3.2,2.1,4,3.8c0.1,0.2,0.3,0.3,0.5,0.3
# 	c0.1,0,0.1,0,0.2,0c0.3-0.1,0.4-0.4,0.3-0.7c-0.9-2-2.5-3.5-4.6-4.4C9.3,3.5,9,3.6,8.9,3.8C8.8,4.1,8.9,4.4,9.2,4.5" style="fill-rule:evenodd;clip-rule:evenodd;">
#               </path>
#               <path d="M17.1,7.6c-1.4-3.1-4-5.6-7.2-6.9c-0.3-0.1-0.6,0-0.7,0.3
# 	c-0.1,0.3,0,0.6,0.3,0.7c3,1.2,5.4,3.4,6.7,6.3c0.1,0.2,0.3,0.3,0.5,0.3c0.1,0,0.1,0,0.2,0C17.1,8.2,17.2,7.9,17.1,7.6" style="fill-rule:evenodd;clip-rule:evenodd;">
#               </path>
#              </svg>
#              <span class="phone-number-container" data-code="JQLJU" data-mobile="" data-origin="detail-sidebar" data-phone="+32 (0)60 30 02 36" data-type="detail">
#               +32 (0)…
#              </span>
#              <a class="phone-number-link" data-code="JQLJU" data-origin="detail-sidebar" data-type="detail" href="#">
#               Montrer le n°
#              </a>
#             </p>
#            </div>
#            <div class="show-on-print">
#             Faubourg Saint-Germain 28
#             <br/>
#             5660
#                 Couvin
#            </div>
#            <div class="clear">
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <section class="section-property-stats align-block-left" id="property-stats">
#         <div class="section-inner">
#          <div class="stat-block views">
#           <div class="stat-text text">
#            <div class="amount">
#             66
#            </div>
#           </div>
#           <div class="subtext">
#            Nombre de vues
#           </div>
#          </div>
#          <div class="stat-block favorites">
#           <div class="stat-text text">
#            0
#            <span class="small">
#             fois
#            </span>
#           </div>
#           <div class="subtext">
#            Propriété Favorite
#           </div>
#          </div>
#          <div class="stat-block quality">
#           <div class="stat-text text">
#            <div class="amount">
#             59
#             <small>
#              %
#             </small>
#             <span class="icon-transparency-block group-3">
#              <span class="zf-icon icon-slot-half-open">
#              </span>
#             </span>
#            </div>
#           </div>
#           <div class="subtext">
#            Transparence
#            <a class="info-link" href="#">
#             <i class="zf-icon icon-info-vol">
#             </i>
#            </a>
#           </div>
#          </div>
#          <div class="stat-block popularity">
#           <div class="stat-text text">
#            <div class="amount">
#             <svg class="popularity-fire fire-1" enable-background="new 0 0 512 512" version="1.1" viewbox="40 0 450 512" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="https://www.w3.org/1999/xlink" y="0px">
#              <path class="path-1" d="M167,4.1c0,0,208.5,17.7,208.5,220.8c0,0,4.1,53.1-9.5,98.1c0,0,39.5,16.4,45-99.5c0,0,34.1,41.1,30,100.3
#                         S387.9,507,252.9,507c-121.3,0-171.7-88.6-171.7-167.6c0-62.7,49.1-105.2,80.4-149.9c19.1-27.3,12.3-76.3,12.3-76.3
#                         s22.3,31.7,25.9,43.6c4.2,14,1.1,65.5,1.1,65.5s38.5-36.9,38.5-91.4C239.3,90.4,213.4,42.3,167,4.1z" fill="#E04A34">
#              </path>
#              <path class="path-2" d="M252.1,232.6c0,0,11.4,10.6,11.4,41.7s-11.4,35.6-18.2,45.5c-20.8,30.1-101.6,50.8-101.6,105.4
#                         s45.9,74.2,73.7,79.6c23.1,4.4,58.3,3.1,78.1-12.3c16.2-12.6,36.3-40.7,36.3-106.7S299.9,282.6,252.1,232.6z" fill="#FF9100">
#              </path>
#              <path class="path-3" d="M262.5,357.4c0,0,3.9,11.7-1.3,27.2c-5.2,15.5-14,22.9-24.9,27.4c-17.7,7.4-49.2,14.8-48.5,41.5
#                         c0.8,28.6,7.7,36.4,17.4,44.5c10.1,8.4,28.5,11.3,40.9,6.9c10.2-3.6,26.5-11.2,37.5-44C294.5,428.1,282.9,392.1,262.5,357.4z" fill="#FFBB00">
#              </path>
#             </svg>
#             <svg class="popularity-fire fire-2 fire-inactive" enable-background="new 0 0 512 512" version="1.1" viewbox="40 0 450 512" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="https://www.w3.org/1999/xlink" y="0px">
#              <path class="path-1" d="M167,4.1c0,0,208.5,17.7,208.5,220.8c0,0,4.1,53.1-9.5,98.1c0,0,39.5,16.4,45-99.5c0,0,34.1,41.1,30,100.3
#                         S387.9,507,252.9,507c-121.3,0-171.7-88.6-171.7-167.6c0-62.7,49.1-105.2,80.4-149.9c19.1-27.3,12.3-76.3,12.3-76.3
#                         s22.3,31.7,25.9,43.6c4.2,14,1.1,65.5,1.1,65.5s38.5-36.9,38.5-91.4C239.3,90.4,213.4,42.3,167,4.1z" fill="#E04A34">
#              </path>
#              <path class="path-2" d="M252.1,232.6c0,0,11.4,10.6,11.4,41.7s-11.4,35.6-18.2,45.5c-20.8,30.1-101.6,50.8-101.6,105.4
#                         s45.9,74.2,73.7,79.6c23.1,4.4,58.3,3.1,78.1-12.3c16.2-12.6,36.3-40.7,36.3-106.7S299.9,282.6,252.1,232.6z" fill="#FF9100">
#              </path>
#              <path class="path-3" d="M262.5,357.4c0,0,3.9,11.7-1.3,27.2c-5.2,15.5-14,22.9-24.9,27.4c-17.7,7.4-49.2,14.8-48.5,41.5
#                         c0.8,28.6,7.7,36.4,17.4,44.5c10.1,8.4,28.5,11.3,40.9,6.9c10.2-3.6,26.5-11.2,37.5-44C294.5,428.1,282.9,392.1,262.5,357.4z" fill="#FFBB00">
#              </path>
#             </svg>
#             <svg class="popularity-fire fire-3 fire-inactive" enable-background="new 0 0 512 512" version="1.1" viewbox="40 0 450 512" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="https://www.w3.org/1999/xlink" y="0px">
#              <path class="path-1" d="M167,4.1c0,0,208.5,17.7,208.5,220.8c0,0,4.1,53.1-9.5,98.1c0,0,39.5,16.4,45-99.5c0,0,34.1,41.1,30,100.3
#                         S387.9,507,252.9,507c-121.3,0-171.7-88.6-171.7-167.6c0-62.7,49.1-105.2,80.4-149.9c19.1-27.3,12.3-76.3,12.3-76.3
#                         s22.3,31.7,25.9,43.6c4.2,14,1.1,65.5,1.1,65.5s38.5-36.9,38.5-91.4C239.3,90.4,213.4,42.3,167,4.1z" fill="#E04A34">
#              </path>
#              <path class="path-2" d="M252.1,232.6c0,0,11.4,10.6,11.4,41.7s-11.4,35.6-18.2,45.5c-20.8,30.1-101.6,50.8-101.6,105.4
#                         s45.9,74.2,73.7,79.6c23.1,4.4,58.3,3.1,78.1-12.3c16.2-12.6,36.3-40.7,36.3-106.7S299.9,282.6,252.1,232.6z" fill="#FF9100">
# ...
#          <i class="zf-icon icon-whatsapp">
#          </i>
#         </a>
#        </div>
#       </div>
#       <!-- .footer-right-inner -->
#      </div>
#      <!-- .footer-right -->
#      <div class="footer-left">
#       <div class="copyright">
#        <small>
#         Copyright © 2007 - 2020 par
#         <img alt="zimmo.be" height="15" src="/public/images/logo/default/zimmo-logo.svg" title="zimmo.be" width="76"/>
#        </small>
#        <br/>
#        <a data-ga="Footer,click,Disclaimer" href="https://www.mediahuis.be/fr/contrat-utilisation-services/" target="_blank">
#         Conditions d'utilisation
#        </a>
#        -
#        <a data-ga="Footer,click,Cookies" href="https://www.mediahuis.be/fr/contrat-utilisation-services" target="_blank">
#         Contrat pour l’utilisation des Services
#        </a>
#        -
#        <a data-ga="Footer,click,Cookies" href="https://www.mediahuis.be/fr/politique-de-cookies" target="_blank">
#         Politique Cookies
#        </a>
#        -
#        <a data-ga="Footer,click,Privacy" href="https://www.mediahuis.be/fr/privacy-policy/" target="_blank">
#         Privacy policy
#        </a>
#        -
#        <a class="showConsentPreferences" href="javascript:void(0)">
#         Gérer les cookies
#        </a>
#        -
#        <a data-ga="Footer,click,SalesConditions" href="https://www.mediahuis.be/fr/conditions-de-vente/" target="_blank">
#         Conditions de vente
#        </a>
#        |
#        <a data-ga="Footer,click,All cities" href="/fr/commune/alfabetique/">
#         Communes
#        </a>
#        (Server: 92)
#       </div>
#      </div>
#      <!-- .footer-left -->
#     </div>
#    </section>
#    <div id="mobileMenu">
#     <div>
#      <nav class="collapse-menu">
#       <ul>
#        <li class="">
#         <a href="https://www.zimmo.be/fr/">
#          <span class="menu-text-label">
#           Home
#          </span>
#         </a>
#        </li>
#        <li class="hasChildren">
#         <span>
#          Rechercher
#         </span>
#         <ul>
#          <li class="">
#           <a href='javascript:app.openAdvancedSearchMenu({status:"1"},null, {titleKey: "menu.properties.search_for_sale"})'>
#            <span class="menu-text-label">
#             A vendre
#            </span>
#           </a>
#          </li>
#          <li class="">
#           <a href='javascript:app.openAdvancedSearchMenu({status:"2"},null, {titleKey: "menu.properties.search_for_rent"})'>
#            <span class="menu-text-label">
#             A louer
#            </span>
#           </a>
#          </li>
#          <li class="">
#           <a href='javascript:app.openAdvancedSearchMenu({newConstructionOnly:true,projectsOnly:true},null, {titleKey: "menu.properties.search_new_projects"})'>
#            <span class="menu-text-label">
#             Projets neufs
#            </span>
#           </a>
#          </li>
#          <li class="">
#           <a href='javascript:app.openAdvancedSearchMenu({type: ["4"]},null, {titleKey: "menu.properties.search_commercial_real_estate", commercial: true})'>
#            <span class="menu-text-label">
#             Biens professionnels
#            </span>
#           </a>
#          </li>
#          <li class="">
#           <a href='javascript:app.openAdvancedSearchMenu({filterInvestments: true},null, {titleKey: "menu.properties.search_investment_properties"})'>
#            <span class="menu-text-label">
#             Immeubles de rapport
#            </span>
#           </a>
#          </li>
#          <li class="">
#           <a href="https://www.zimmo.be/fr/indicateur-de-prix/">
#            <span class="menu-text-label">
#             Indicateur de prix
#            </span>
#           </a>
#          </li>
#          <li class="">
#           <a href="javascript:app.openZimmocodeSearch()">
#            <span class="menu-text-label">
#             Code Zimmo
#            </span>
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="hasChildren">
#         <span>
#          Mon Zimmo
#         </span>
#         <ul>
#          <li class="">
#           <a href="https://www.zimmo.be/fr/monzimmo/login/">
#            <span class="menu-text-label">
#             Se connecter
#            </span>
#           </a>
#          </li>
#          <li class="">
#           <a href="https://www.zimmo.be/fr/monzimmo/enregistrer/">
#            <span class="menu-text-label">
#             Enregistrer
#            </span>
#           </a>
#          </li>
#          <li class="">
#           <a href="https://www.zimmo.be/fr/monzimmo/biens/">
#            <span class="menu-text-label">
#             Biens favoris
#            </span>
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="hasChildren">
#         <span>
#          Plus
#         </span>
#         <ul>
#          <li class="">
#           <a href="https://www.zimmo.be/fr/page/publicite/">
#            <span class="menu-text-label">
#             Publicité
#            </span>
#           </a>
#          </li>
#          <li class="">
#           <a href="https://www.zimmo.be/blog/?lang=fr" target='"_blank"'>
#            <span class="menu-text-label">
#             Blog
#            </span>
#           </a>
#          </li>
#          <li class="">
#           <a href="https://www.zimmo.be/fr/simulation-pr%C3%AAt-hypoth%C3%A9caire/">
#            <span class="menu-text-label">
#             Simulateur de prêt
#            </span>
#           </a>
#          </li>
#          <li class="">
#           <a href="https://www.zimmo.be/fr/page/biens-a-flirter/">
#            <span class="menu-text-label">
#             A flirter
#            </span>
#           </a>
#          </li>
#          <li class="">
#           <a href="https://www.zimmo.be/fr/page/je_suis_professionnel/">
#            <span class="menu-text-label">
#             Zimmo for Business pour les agents immobiliers
#            </span>
#           </a>
#          </li>
#          <li class="">
#           <a href="https://www.zimmo.be/fr/professionel-immobilier/">
#            <span class="menu-text-label">
#             Chercher un professionnel de l'immobilier
#            </span>
#           </a>
#          </li>
#          <li class="">
#           <a href="https://www.zimmo.be/fr/questions-frequemment-posees/">
#            <span class="menu-text-label">
#             Questions fréquemment posées
#            </span>
#           </a>
#          </li>
#          <li class="hasChildren">
#           <a href="https://www.zimmo.be/fr/page/a_propos/">
#            <span class="menu-text-label">
#             À propos de Zimmo
#            </span>
#           </a>
#           <ul>
#            <li class="">
#             <a href="https://www.zimmo.be/fr/page/a_propos/">
#              <span class="menu-text-label">
#               Qui sommes-nous ?
#              </span>
#             </a>
#            </li>
#            <li class="">
#             <a href="https://www.zimmo.be/fr/jobs/">
#              <span class="menu-text-label">
#               Travailler chez Zimmo
#              </span>
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="">
#           <a href="https://www.zimmo.be/fr/jobs/">
#            <span class="menu-text-label">
#             Travailler chez Zimmo
#            </span>
#           </a>
#          </li>
#          <li class="">
#           <a href="https://www.zimmo.be/fr/page/contact/">
#            <span class="menu-text-label">
#             Contact
#            </span>
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="hasChildren">
#         <span>
#          Choix de la langue
#         </span>
#         <ul>
#          <li class="">
#           <a href="https://www.zimmo.be/nl/couvin-5660/te-koop/huis/JQLJU/?search=82d1fed181cf30aaa8408f90d99003d3">
#            <span class="menu-text-label">
#             Nederlands
#            </span>
#           </a>
#          </li>
#          <li class="disabled">
#           <a href="https://www.zimmo.be/fr/couvin-5660/a-vendre/maison/JQLJU/?search=82d1fed181cf30aaa8408f90d99003d3">
#            <span class="menu-text-label">
#             Français
#            </span>
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="">
#         <a href="https://www.zimmo.be/fr/page/contact/">
#          <span class="menu-text-label">
#           Contact
#          </span>
#         </a>
#        </li>
#       </ul>
#      </nav>
#     </div>
#    </div>
#    <script src="/bundles/fosjsrouting/js/router.js">
#    </script>
#    <script src="/v4/js/fos_js_routes.js?date=201911230916">
#    </script>
#    <script>
#     var DEBUG = false;
#     window._URLS = {
#         dialogLoginLink: '/fr/social/loginfacebook/',
#         advertise: '/fr/page/publicite/',
#         OfficeBoxSearch: "\/fr\/professionel-immobilier\/",
#         disclaimer: "https://www.mediahuis.be/fr/contrat-utilisation-services/",
#         landingpage2: "/fr/zimmy-decouvrez-plus-des-biens/"
#     };
#    </script>
#    <script src="/public/webpack/base.js?v=8e18b">
#    </script>
#    <script src="/public/webpack/property_detail.js?v=6bd91">
#    </script>
#    <script src="/public/js/labels_fr.js?ts=1605164392">
#    </script>
#    <!--[if IE]>
# <script src="//cdnjs.cloudflare.com/ajax/libs/jquery-placeholder/2.0.8/jquery.placeholder.js"></script>
# <script>
#     $(function() {$("input,textarea").placeholder()});
# </script>
# <![endif]-->
#    <script>
#     app.debug = false;
#     app.urls = window._URLS;
#     var LOCALE = 'fr',
#         _locale = 'fr',
#         FUTURE = false,
#         base_dir = app.basedir = '/var/www/vhosts/zimmo.be/httpdocs/',
#         CDN_DOMAINS = app.cdn_domains = ["www01.zimmo.be","www02.zimmo.be","www03.zimmo.be","www04.zimmo.be"],
#         USER_API_URL = app.user_api_url = "https:\/\/user-api.zimmo.be",
#         MY_ZIMMO_API_URL = app.my_zimmo_api_url = "https:\/\/my.zimmo.be",
#         ZIMMO_SHOP_URL = app.zimmo_shop_url = "https:\/\/shop.zimmo.be",
#         base_url = app.base_url = 'https://www.zimmo.be',
#         FB_APP_ID = '270720989678462';
#     app.policy = null;
#
#     /**
#      * Global scope settings for Sentry
#      */
#     Sentry.configureScope(function(scope) {
#         if (typeof app.user !== "undefined") {
#             scope.setUser({
#                 userId: app.user.get("id"),
#                 userLocale: app.user.get("locale")
#             });
#         } else {
#             scope.setUser({
#                 user: "anonymous"
#             });
#         }
#     });
#    </script>
#    <script>
#     $(function() {
#         app.start({
#             el: $('body'),
#             property: {
#                 uuid: '1a541813-75dc-4f7a-8119-b6e9e3d9bc24',
#                 code: 'JQLJU',
#                 subtype: 'Maison',
#                 type: 'Maison',
#                 type_id: '5',
#                 status: 'general.status.for_sale',
#                 status_id: '1',
#                 prijs: 165000.00,
#                 straat: '',
#                 nummer: '',
#                 gemeente: 'Couvin',
#                 address: '',
#                 aantal_slaapkamers: '4',
#                 verwarming: '0',
#                 woonopp: '135',
#                 grondopp: '130',
#                 postcode: '5660',
#                 lat: '50.050100000',
#                 lon: '4.495700000',
#                 reloadOffice: true,
#                 bouwjaar: '',
#                 constructionType: '2-façades',
#                 renovatiejaar: '',
#                 nieuwbouw: false,
#                 zimmo_kantoor_id: '11801',
#                 hoofdFoto: 'https://files.zimmo.be/aD0rGlrr6h-XsQlXE2w-bfmMGwc=/310x231/filters:image-format(pjpg)/d7/c6/a23a-f989-4ae5-80d6-ae98a93fdb4b/foto_zimmo_a815fe85e1982156d202bae583f41031.jpg',
#                 fotoAmount: '24',
#                 epc: '284',
#                 energyLabelCategory: '',
#                 deelgemeente_id: '1476',
#                 url: "https:\/\/immoleseauxvives.be\/bien\/2707",
#                 klein_beschrijf: true,
#                 cadastralIncome: '545',
#                 destination: '0',
#                 plotCost: '',
#                 taxableBy6: '',
#                 taxableBy12: '',
#                 url_responsive: false,
#                 proj_id: 0,
#                 popularity: 1,
#                 mobiScore: null,
#                 show_website: true,
#                 advertiser: {"name":"Immo Les Eaux Vives","phone":"+32 (0)60 30 02 36","mobile":"","showEmail":"1","officeType":"0","useZimmoDetail":"0","pictureZoomPercentage":"0","pictureLogoPosition":"0","pictureApplyMainOnly":"0","officebox":"0","officebox_url":"https:\/\/www.zimmo.be\/fr\/agence-immobiliere\/couvin-5660\/immo-les-eaux-vives-37225\/","name_prefix":""},
#                 isPromoted: true,
#                 iframeHeight: 2300,
#                 transparency: {"main":{"price":{"amount":16,"max":16},"street":{"amount":0,"max":13},"number":{"amount":0,"max":3},"has_photo":{"amount":8,"max":8},"photo_amount":{"amount":5,"max":5},"bedrooms":{"amount":6,"max":6},"living_area_surface":{"amount":2,"max":2},"land_surface":{"amount":2,"max":2}},"bonus":{"price_history":{"amount":20,"max":20},"market_comparison":{"amount":0,"max":20},"virtual_tour":{"amount":0,"max":5}}},
#                 transparencyScore: '',
#                 zmvPrijs: '',
#                 is_zprijs_zichtbaar: '1',
#                 virtueel_bezoek: '',
#                 parcelId: "",
#                 isPlus: "0",
#                 constructionState: "",
#                 publicSaleId: '',
#                 title: "Maison \u00e0 vendre \u00e0 Couvin pour \u20ac 165.000 avec 4 chambres",
#                 boosted: false,
#                 coronaDirect: {"building":"","contents":"","family":""},
#                 province: "Namur",
#                             },
#             sellerType: 'Vendeur',
#             page: 'property',
#             isCrawler: false,
#             news: null,
#             loadStats: true,
#             search: {"region":{"type":"none"},"status":"1","type":["5"],"subType":[],"makelaar":null,"miKantoor":null,"netwerk":null,"makelaarsgroep":null,"hash":"82d1fed181cf30aaa8408f90d99003d3","priceMin":null,"priceMax":null,"priceIncludeUnknown":true,"priceChangedOnly":false,"bedroomsMin":null,"bedroomsMax":null,"bedroomsIncludeUnknown":true,"bathroomsMin":null,"bathroomsMax":null,"bathroomsIncludeUnknown":true,"constructionType":[],"constructionIncludeUnknown":true,"livingAreaMin":null,"livingAreaMax":null,"livingAreaIncludeUnknown":true,"landAreaMin":null,"landAreaMax":null,"landAreaIncludeUnknown":true,"commercialAreaMin":null,"commercialAreaMax":null,"commercialAreaIncludeUnknown":true,"yearOfConstructionMin":null,"yearOfConstructionMax":null,"yearOfConstructionIncludeUnknown":true,"epcMin":null,"epcMax":null,"epcIncludeUnknown":true,"hasGarden":null,"hasTerrasse":null,"hasGarage":null,"hasFurniture":null,"newConstructionOnly":null,"projectsOnly":null,"filterPublicSales":null,"filterInvestments":null,"query":null,"queryCondition":"and","includeNoPhotos":true,"includeNoAddress":true,"onlyRecent":false,"onlyRecentlyUpdated":false,"nieuwSinds":null,"lastPriceDrop":null,"minPrecision":null,"maxPrecision":null,"isPlus":false,"excludedEstates":[],"notarySaleTypeIds":null,"notarySale":null},
#             searchTerms: [],
#             energyData: null,
#             loanSimulation: {"loan15":935.29494523736,"loan20":745.92730110878,"loan25":633.63628535913,"registration":23626.63,"loanCosts":3373.9432},
#             plusToken: '',
#         });
#
#         app.TrackingCodeHandler.call("criteo", function() {
#             if (typeof window.criteo_q === 'undefined') {
#                 window.criteo_q = [];
#             }
#             window.criteo_q.push(
#                 {event: "viewItem", item: "JQLJU"}
#             );
#         });
#     });
#         $(function () {
#             app.TrackingCodeHandler.call("DoubleclickFloodlight");
#             app.TrackingCodeHandler.call("Hotjar");
#             app.TrackingCodeHandler.call("CxenseAndEnreach");
#
#         });
#    </script>
#    <script>
#     $(function() {
#         app.TrackingCodeHandler.call("GoogleAnalytics", function() {
#
#                     });
#     });
#    </script>
#    <script>
#     $(function() {
#         app.TrackingCodeHandler.call("gemius");
#     });
#    </script>
#   </div>
#  </body>
# </html>

# %%
#locality

loc = soup.find("h2", class_="section-title").text
loc = loc.split()
for x in loc:
    if re.match("^[0-9]{4}",x):
        loc = x
        print(loc)
# Out:
# 5660

# %%
#function for determine type and subtype of property
def itemType(var):
    var = soup.find('ul', class_="main-features").text
    var = var.split('Type')
    var = var[1]
    var = var.split('\n')
    var = var[1]
    return var

# %%
a = itemType('var')
a.split('(Maison)')
# Out:
# ['Maison']

# %%
#subtype of property
equiv2 = itemType('var')   # call the function
#equiv2
if len(equiv2) > 10:
    type_check2 = re.search('Maison', equiv2)

    if type_check2 != 'None':
        subtype = equiv2.split('(Maison)')
        subtype = subtype[0]
        print(subtype)
    else:
        subtype = equiv2.split('(Apartment)')
        subtype = subtype[0]
        print(subtype)
else:
    print('None')
#suitemType('subtype')
# Out:
# None

# %%
#determining the price

try:   
    price = soup.find('span', class_="feature-value").text
    price = price.split("\n")
    price = price[4]
    price = price.strip()
    price = price.split(" ")
    price = price[1]
    price = price.replace('.', '')
    price = int(price)

    print(price)
    
except IndexError:
    print('None')
# Out:
# 165000

# %%
#number of rooms

try:
    rooms = soup.find('ul', class_="main-features").text
    rooms = rooms.split('Chambres')
    rooms = rooms[1]
    rooms = rooms.split('\n')
    rooms = rooms[2]
    rooms = rooms.strip()
    rooms = int(rooms)


    print(rooms)

except ValueError:
    print('None')
# Out:
# 4

# %%
#Area

try:
    surf = soup.find('ul', class_="main-features").text
    surf = surf.split('Surf. habitable\n\n')
    surf = surf[1]
    surf = surf.split('\n')
    surf = surf[0]
    surf = surf.strip()
    surf = surf.split(' ')
    surf = surf[0]
    surf = int(surf)

    print(surf)

except ValueError:
    print('None')
# Out:
# 135

# %%
#private bathroom

try:
    bathroom = soup.find('ul', class_="main-features").text
    bathroom = bathroom.split('Salles de bain\n\n')
    bathroom = bathroom[1]
    bathroom = bathroom.split('\n')
    bathroom = bathroom[0]
    bathroom = bathroom.strip()
    bathroom = int(bathroom)

    print(bathroom)

except IndexError:
    print('None')
# Out:
# 1

# %%
#State of the building
    #year of build
    
build_year = soup.find('ul', class_="main-features").text
build_year = build_year.split('Construit en\n\n')
build_year = build_year[1]
build_year = build_year.split('\n')
build_year = build_year[0]
build_year = build_year.split('»')
build_year = build_year[0]
build_year = build_year.strip()

#build_year

if build_year == 'sur demande':
    print("None")
else: 
    if int(build_year) >= 2000:
        State_of_the_building = 'New'
        print(State_of_the_building)

    elif int(build_year) < 2000 and int(build_year) > 1980:
        State_of_the_building = 'fairly new'
        print(State_of_the_building)

    elif int(build_year) < 1980:
        State_of_the_building = 'to be renovated'
        print(State_of_the_building)
# Out:
# None

# %%
#Surface area of the plot of land

if typ_prop == "Maison":
   try:
      Surfac_land = soup.find('ul', class_="main-features").text
      Surfac_land = Surfac_land.split('Sup. du terrain\n\n')
      Surfac_land = Surfac_land[1]
      Surfac_land = Surfac_land.split('\n')
      Surfac_land = Surfac_land[0]
      Surfac_land = Surfac_land.strip()
      Surfac_land = Surfac_land.split(' ')
      Surfac_land = Surfac_land[0]
      Surfac_land = int(Surfac_land)
      print(Surfac_land)
   except ValueError:
      print('None')
else:
    print('None')
# Out:
# None

# %%
#Number of facades

if typ_prop == "Maison":
    facades = soup.find('ul', class_="main-features").text
    facades = facades.split('Construction\n\n')
    facades = facades[1]
    facades = facades.split('-')
    facades = facades[0]
    facades = facades.strip()
    facades = int(facades)
    print(facades)
else:
    print('None')
# Out:
# None

# %%
#garden 'ungiven area'
garden = soup.find('section', class_="section-overige overige").text
garden = garden.split('\n\n\n\n')
garden = garden[1]
garden = garden.split('\n')
garden = garden[0]

#garden
if garden == 'Jardin':
    print('True')
else:
    print('False')
# Out:
# True

# %%
#Terasse

try:
    terrace = soup.find('div', class_="column-right").text
    terrace = terrace.split('Disposition\n\n\n\n')
    terrace = terrace[1]
    terrace = terrace.split('\n')
    terrace = terrace[0]

    if terrace == 'Terrasse':
        print('Yes')
    else:
        print('No')

except IndexError:
    print('No')
# Out:
# No

# %%
#furnished
#declare a 'No' value when i != 'Yes'

furn = soup.find('section', class_="section-comfort").text
furn = furn.split('\n')
for i in furn:
    if i == 'Meublé':
        print('Yes')
